# %%
#import libaries
import pandas as pd
import requests
import numpy as np
import sql
import matplotlib as mp
import seaborn as sb

# %%
#install the SQL libary
# !pip install ipython-sql

# %%
#Create connection to database file
#database = "housing_prices.project.db"
#connection = sql.connect(database)

# %%
# create a dataframe to import data for the tutorial
df = pd.read_csv("/Users/meikimura/Downloads/housing_prices_project.csv")
# df= pd.DataFrame({'name': ['Juan', 'Victoria', 'Mary'], 
#                   'age': [23,34,43], 
#                   'city': ['Miami', 'Buenos Aires','Santiago']})

df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# We will sqlite3 library and create a connection
cnn = sqlite3.connect('housing_prices_project.db')

df.to_sql('test', cnn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/5m/rj2gngn9439_0t55tnxm3_1m0000gn/T/ipykernel_4526/742280512.py in <module>
#       1 # We will sqlite3 library and create a connection
# ----> 2 cnn = sqlite3.connect('housing_prices_project.db')
#       3
#       4 df.to_sql('test', cnn)
#
# NameError: name 'sqlite3' is not defined

# %%
# %load_ext sql

# %%
# %sql sqlite:///housing_prices_project.db

# %%
#Answer the following questions in both Python and SQL, the results should return the same.

# %%
# Question 1: How many houses were sold per year?

# %%
# %%sql
# SELECT *
# FROM test
# Out:
#  * sqlite:///housing_prices_project.db
#    sqlite:///jupyter_sql_tutorial.db
# (sqlite3.OperationalError) no such table: test
# [SQL: SELECT *
# FROM test]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# Python

# Convert the 'YrSold' column to datetime type (if not already)
#df['YrSold'] = pd.to_datetime(df['YrSold'], format='%Y')

# Extract the year from the 'YrSold' column and count the occurrences
year_counts = df['YrSold'].value_counts()

# Print the result
print(year_counts)
# Out:
# 2009    338
# 2007    329
# 2006    314
# 2008    304
# 2010    175
# Name: YrSold, dtype: int64

# %%
#make a chart

# %%
# Question 2: What is the percentage of houses with garages that were built after the original house?

# %%
#SQL
WITH a as (
    SELECT
        COUNT(*) as n_houses
    FROM
        data
),

l as (
        SELECT
            COUNT(*) as n_houses_w_garage_later
        FROM
            data
        WHERE
            CAST(YearBuilt as string) < GarageYrBlt
            AND
            GarageYrBlt <> 'NA'
)

SELECT
    a.n_houses,
    l.n_houses_w_garage_later,
    a.n_houses - l.n_houses_w_garage_later as n,
    ROUND(100.0*l.n_houses_w_garage_later/a.n_houses, 1) as rate_houses_w_garage_later
FROM
    a
    CROSS JOIN
    l

# %%
# Python

df = data.copy()

df['GarageYrBlt'] = df['GarageYrBlt'].replace('NA', 0).astype(int)


matching_rows = df[df['GarageYrBlt'] > df['YearBuilt']]

display(len(data))

display(len(matching_rows))

percentage = round((len(matching_rows) / len(data)) * 100,1)

print(f"Percentage of matching years: {percentage}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/5m/rj2gngn9439_0t55tnxm3_1m0000gn/T/ipykernel_1082/3900698161.py in <module>
#       1 # Python
#       2
# ----> 3 df = data.copy()
#       4
#       5 df['GarageYrBlt'] = df['GarageYrBlt'].replace('NA', 0).astype(int)
#
# NameError: name 'data' is not defined

# %%
#make a chart

# %%
# Question 3: What is the relationship between the year that the house was built and the price?

# %%
#SQL
SELECT YearBuilt, AVG(SalePrice) AS average_sale_price
FROM train.csv
GROUP BY YearBuilt
ORDER BY YearBuilt ASC
# Out:
#   File "/var/folders/5m/rj2gngn9439_0t55tnxm3_1m0000gn/T/ipykernel_1082/80300485.py", line 2
#     SELECT YearBuilt, AVG(SalePrice) AS average_sale_price
#            ^
# SyntaxError: invalid syntax

# %%
#Python

correlation = df['YearBuilt'].corr(df['SalePrice'])
print("Correlation coefficient:", correlation)
# Out:
# Correlation coefficient: 0.5228973328794969

# %%
#make a chart
